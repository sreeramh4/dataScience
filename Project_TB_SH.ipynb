# %% [markdown]
# # Project 1: Deaths by tuberculosis
#
# by Michel Wermelinger and Sreeram H, 14 July 2015, edited 5 April 2016, updated 18 October, 20 December 2017 and0 November 2018
#
# This is the project notebook for the first part of The Open University's _Learn to code for Data Analysis_ course.
#
# In 2000, the United Nations set eight Millenium Development Goals (MDGs) to reduce poverty and diseases, improve gender equality and environmental sustainability, etc. Each goal is quantified and time-bound, to be achieved by the end of 2015. Goal 6 is to have halted and started reversing the spread of HIV, malaria and tuberculosis (TB).
# TB doesn't make headlines like Ebola, SARS (severe acute respiratory syndrome) and other epidemics, but is far deadlier. For more information, see the World Health Organisation (WHO) page <http://www.who.int/gho/tb/en/>.
#
# Given the population and number of deaths due to TB in some countries during one year, the following questions will be answered:
#
# - What is the total, maximum, minimum and average number of deaths in that year?
# - Which countries have the most and the least deaths?
# - What is the death rate (deaths per 100,000 inhabitants) for each country?
# - Which countries have the lowest and highest death rate?
#
# The death rate allows for a better comparison of countries with widely different population sizes.

# %% [markdown]
# ## The data
#
# The data consists of total population and total number of deaths due to TB (excluding HIV) in 2013 in each of the Common Wealth of Nations
#
# The data was taken in July 2015 from <http://apps.who.int/gho/data/node.main.POP107?lang=en> (population) and <http://apps.who.int/gho/data/node.main.1317?lang=en> (deaths). The uncertainty bounds of the number of deaths were ignored.
#
# The data was collected into an Excel file which should be in the same folder as this notebook.

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

from pandas import *
data = read_excel('WHO POP TB subset.xls')
data
# Out:
#                                               Country  Population (1000s)  \
# 0                                 Antigua and Barbuda                  90
# 1                                           Australia               23343
# 2                                             Bahamas                 377
# 3                                            Barbados                 285
# 4                                              Belize                 332
# 5                                            Botswana                2021
# 6                                   Brunei Darussalam                 418
# 7                                            Cameroon               22254
# 8                                              Canada               35182
# 9                                              Cyprus                1141
# 10                                           Dominica                  72
# 11                                               Fiji                 881
# 12                                             Gambia                1849
# 13                                              Ghana               25905
# 14                                            Grenada                 106
# 15                                             Guyana                 800
# 16                                              India             1252140
# 17                                            Jamaica                2784
# 18                                              Kenya               44354
# 19                                           Kiribati                 102
# 20                                            Lesotho                2074
# 21                                             Malawi               16363
# 22                                           Malaysia               29717
# 23                                              Malta                 429
# 24                                          Mauritius                1244
# 25                                         Mozambique               25834
# 26                                            Namibia                2303
# 27                                              Nauru                  10
# 28                                        New Zealand                4506
# 29                                            Nigeria              173615
# 30                                           Pakistan              182143
# 31                                   Papua New Guinea                7321
# 32                                             Rwanda               11777
# 33                              Saint Kitts and Nevis                  54
# 34                                        Saint Lucia                 182
# 35                   Saint Vincent and the Grenadines                 109
# 36                                              Samoa                 190
# 37                                         Seychelles                  93
# 38                                       Sierra Leone                6092
# 39                                          Singapore                5412
# 40                                    Solomon Islands                 561
# 41                                       South Africa               52776
# 42                                          Sri Lanka               21273
# 43                                              Tonga                 105
# 44                                Trinidad and Tobago                1341
# 45                                             Tuvalu                  10
# 46                                             Uganda               37579
# 47  United Kingdom of Great Britain and Northern I...               63136
# 48                        United Republic of Tanzania               49253
# 49                                            Vanuatu                 253
# 50                                             Zambia               14539
#
#     TB deaths
# 0        1.20
# 1       45.00
# 2        1.80
# 3        2.00
# 4       20.00
# 5      440.00
# 6       13.00
# 7     7800.00
# 8       62.00
# 9        2.30
# 10       2.70
# 11      37.00
# 12     370.00
# 13    1100.00
# 14       1.10
# 15     130.00
# 16  240000.00
# 17      17.00
# 18    9100.00
# 19      30.00
# 20     960.00
# 21    1500.00
# 22    1700.00
# 23       1.50
# 24      15.00
# 25   18000.00
# 26    1300.00
# 27       0.67
# 28       6.30
# 29  160000.00
# 30   49000.00
# 31    2400.00
# 32     810.00
# 33       1.60
# 34       2.20
# 35       3.10
# 36       6.10
# 37       1.40
# 38    2600.00
# 39      94.00
# 40      81.00
# 41   25000.00
# 42    1300.00
# 43       2.50
# 44      29.00
# 45       2.80
# 46    4100.00
# 47     340.00
# 48    6000.00
# 49      16.00
# 50    3600.00

# %% [markdown]
# ## The range of the problem
#
# The column of interest is the last one.

# %%
tbColumn = data['TB deaths']

# %% [markdown]
# The total number of deaths in 2013 is:

# %%
tbColumn.sum()
# Out:
# 538048.2699999999

# %% [markdown]
# The largest and smallest number of deaths in a single country are:

# %%
tbColumn.max()
# Out:
# 240000.0

# %%
tbColumn.min()
# Out:
# 0.67

# %% [markdown]
# From less than 1 death in the island nation Nauru to almost a quarter of a million deaths in India is a huge range. The average number of deaths, over all countries in the data, can give a better idea of the seriousness of the problem in each country.
# The average can be computed as the mean or the median. Given the wide range of deaths, the median is probably a more sensible average measure.

# %%
tbColumn.mean()
# Out:
# 10549.966078431371

# %%
tbColumn.median()
# Out:
# 62.0

# %% [markdown]
# The median is far lower than the mean. This indicates that some of the countries had a very high number of TB deaths in 2013, pushing the value of the mean up.

# %% [markdown]
# ## The most affected
#
# To see the most affected countries, the table is sorted in ascending order by the last column, which puts those countries in the last rows.

# %%
data.sort_values('TB deaths')
# Out:
#                                               Country  Population (1000s)  \
# 27                                              Nauru                  10
# 14                                            Grenada                 106
# 0                                 Antigua and Barbuda                  90
# 37                                         Seychelles                  93
# 23                                              Malta                 429
# 33                              Saint Kitts and Nevis                  54
# 2                                             Bahamas                 377
# 3                                            Barbados                 285
# 34                                        Saint Lucia                 182
# 9                                              Cyprus                1141
# 43                                              Tonga                 105
# 10                                           Dominica                  72
# 45                                             Tuvalu                  10
# 35                   Saint Vincent and the Grenadines                 109
# 36                                              Samoa                 190
# 28                                        New Zealand                4506
# 6                                   Brunei Darussalam                 418
# 24                                          Mauritius                1244
# 49                                            Vanuatu                 253
# 17                                            Jamaica                2784
# 4                                              Belize                 332
# 44                                Trinidad and Tobago                1341
# 19                                           Kiribati                 102
# 11                                               Fiji                 881
# 1                                           Australia               23343
# 8                                              Canada               35182
# 40                                    Solomon Islands                 561
# 39                                          Singapore                5412
# 15                                             Guyana                 800
# 47  United Kingdom of Great Britain and Northern I...               63136
# 12                                             Gambia                1849
# 5                                            Botswana                2021
# 32                                             Rwanda               11777
# 20                                            Lesotho                2074
# 13                                              Ghana               25905
# 42                                          Sri Lanka               21273
# 26                                            Namibia                2303
# 21                                             Malawi               16363
# 22                                           Malaysia               29717
# 31                                   Papua New Guinea                7321
# 38                                       Sierra Leone                6092
# 50                                             Zambia               14539
# 46                                             Uganda               37579
# 48                        United Republic of Tanzania               49253
# 7                                            Cameroon               22254
# 18                                              Kenya               44354
# 25                                         Mozambique               25834
# 41                                       South Africa               52776
# 30                                           Pakistan              182143
# 29                                            Nigeria              173615
# 16                                              India             1252140
#
#     TB deaths
# 27       0.67
# 14       1.10
# 0        1.20
# 37       1.40
# 23       1.50
# 33       1.60
# 2        1.80
# 3        2.00
# 34       2.20
# 9        2.30
# 43       2.50
# 10       2.70
# 45       2.80
# 35       3.10
# 36       6.10
# 28       6.30
# 6       13.00
# 24      15.00
# 49      16.00
# 17      17.00
# 4       20.00
# 44      29.00
# 19      30.00
# 11      37.00
# 1       45.00
# 8       62.00
# 40      81.00
# 39      94.00
# 15     130.00
# 47     340.00
# 12     370.00
# 5      440.00
# 32     810.00
# 20     960.00
# 13    1100.00
# 42    1300.00
# 26    1300.00
# 21    1500.00
# 22    1700.00
# 31    2400.00
# 38    2600.00
# 50    3600.00
# 46    4100.00
# 48    6000.00
# 7     7800.00
# 18    9100.00
# 25   18000.00
# 41   25000.00
# 30   49000.00
# 29  160000.00
# 16  240000.00

# %% [markdown]
# The table raises the possibility that a large number of deaths may be partly due to a large population. To compare the countries on an equal footing, the death rate per 100,000 inhabitants is computed.

# %%
populationColumn = data['Population (1000s)']
data['TBdeathsPerMN'] = tbColumn * 100 / populationColumn
data
# Out:
#                                               Country  Population (1000s)  \
# 0                                 Antigua and Barbuda                  90
# 1                                           Australia               23343
# 2                                             Bahamas                 377
# 3                                            Barbados                 285
# 4                                              Belize                 332
# 5                                            Botswana                2021
# 6                                   Brunei Darussalam                 418
# 7                                            Cameroon               22254
# 8                                              Canada               35182
# 9                                              Cyprus                1141
# 10                                           Dominica                  72
# 11                                               Fiji                 881
# 12                                             Gambia                1849
# 13                                              Ghana               25905
# 14                                            Grenada                 106
# 15                                             Guyana                 800
# 16                                              India             1252140
# 17                                            Jamaica                2784
# 18                                              Kenya               44354
# 19                                           Kiribati                 102
# 20                                            Lesotho                2074
# 21                                             Malawi               16363
# 22                                           Malaysia               29717
# 23                                              Malta                 429
# 24                                          Mauritius                1244
# 25                                         Mozambique               25834
# 26                                            Namibia                2303
# 27                                              Nauru                  10
# 28                                        New Zealand                4506
# 29                                            Nigeria              173615
# 30                                           Pakistan              182143
# 31                                   Papua New Guinea                7321
# 32                                             Rwanda               11777
# 33                              Saint Kitts and Nevis                  54
# 34                                        Saint Lucia                 182
# 35                   Saint Vincent and the Grenadines                 109
# 36                                              Samoa                 190
# 37                                         Seychelles                  93
# 38                                       Sierra Leone                6092
# 39                                          Singapore                5412
# 40                                    Solomon Islands                 561
# 41                                       South Africa               52776
# 42                                          Sri Lanka               21273
# 43                                              Tonga                 105
# 44                                Trinidad and Tobago                1341
# 45                                             Tuvalu                  10
# 46                                             Uganda               37579
# 47  United Kingdom of Great Britain and Northern I...               63136
# 48                        United Republic of Tanzania               49253
# 49                                            Vanuatu                 253
# 50                                             Zambia               14539
#
#     TB deaths  TBdeathsPerMN
# 0        1.20       1.333333
# 1       45.00       0.192777
# 2        1.80       0.477454
# 3        2.00       0.701754
# 4       20.00       6.024096
# 5      440.00      21.771400
# 6       13.00       3.110048
# 7     7800.00      35.049879
# 8       62.00       0.176226
# 9        2.30       0.201578
# 10       2.70       3.750000
# 11      37.00       4.199773
# 12     370.00      20.010817
# 13    1100.00       4.246285
# 14       1.10       1.037736
# 15     130.00      16.250000
# 16  240000.00      19.167186
# 17      17.00       0.610632
# 18    9100.00      20.516752
# 19      30.00      29.411765
# 20     960.00      46.287367
# 21    1500.00       9.167023
# 22    1700.00       5.720631
# 23       1.50       0.349650
# 24      15.00       1.205788
# 25   18000.00      69.675621
# 26    1300.00      56.448111
# 27       0.67       6.700000
# 28       6.30       0.139814
# 29  160000.00      92.157936
# 30   49000.00      26.901940
# 31    2400.00      32.782407
# 32     810.00       6.877813
# 33       1.60       2.962963
# 34       2.20       1.208791
# 35       3.10       2.844037
# 36       6.10       3.210526
# 37       1.40       1.505376
# 38    2600.00      42.678923
# 39      94.00       1.736881
# 40      81.00      14.438503
# 41   25000.00      47.370017
# 42    1300.00       6.111033
# 43       2.50       2.380952
# 44      29.00       2.162565
# 45       2.80      28.000000
# 46    4100.00      10.910349
# 47     340.00       0.538520
# 48    6000.00      12.181999
# 49      16.00       6.324111
# 50    3600.00      24.760988

# %%
permnColumn = data['TBdeathsPerMN']
permnColumn.max()
# Out:
# 92.15793566224117

# %%
That would mean Nigeria has the maximum number of deaths per million people

# %%
data.sort_values('TBdeathsPerMN')
# Out:
#                                               Country  Population (1000s)  \
# 28                                        New Zealand                4506
# 8                                              Canada               35182
# 1                                           Australia               23343
# 9                                              Cyprus                1141
# 23                                              Malta                 429
# 2                                             Bahamas                 377
# 47  United Kingdom of Great Britain and Northern I...               63136
# 17                                            Jamaica                2784
# 3                                            Barbados                 285
# 14                                            Grenada                 106
# 24                                          Mauritius                1244
# 34                                        Saint Lucia                 182
# 0                                 Antigua and Barbuda                  90
# 37                                         Seychelles                  93
# 39                                          Singapore                5412
# 44                                Trinidad and Tobago                1341
# 43                                              Tonga                 105
# 35                   Saint Vincent and the Grenadines                 109
# 33                              Saint Kitts and Nevis                  54
# 6                                   Brunei Darussalam                 418
# 36                                              Samoa                 190
# 10                                           Dominica                  72
# 11                                               Fiji                 881
# 13                                              Ghana               25905
# 22                                           Malaysia               29717
# 4                                              Belize                 332
# 42                                          Sri Lanka               21273
# 49                                            Vanuatu                 253
# 27                                              Nauru                  10
# 32                                             Rwanda               11777
# 21                                             Malawi               16363
# 46                                             Uganda               37579
# 48                        United Republic of Tanzania               49253
# 40                                    Solomon Islands                 561
# 15                                             Guyana                 800
# 16                                              India             1252140
# 12                                             Gambia                1849
# 18                                              Kenya               44354
# 5                                            Botswana                2021
# 50                                             Zambia               14539
# 30                                           Pakistan              182143
# 45                                             Tuvalu                  10
# 19                                           Kiribati                 102
# 31                                   Papua New Guinea                7321
# 7                                            Cameroon               22254
# 38                                       Sierra Leone                6092
# 20                                            Lesotho                2074
# 41                                       South Africa               52776
# 26                                            Namibia                2303
# 25                                         Mozambique               25834
# 29                                            Nigeria              173615
#
#     TB deaths  TBdeathsPerMN
# 28       6.30       0.139814
# 8       62.00       0.176226
# 1       45.00       0.192777
# 9        2.30       0.201578
# 23       1.50       0.349650
# 2        1.80       0.477454
# 47     340.00       0.538520
# 17      17.00       0.610632
# 3        2.00       0.701754
# 14       1.10       1.037736
# 24      15.00       1.205788
# 34       2.20       1.208791
# 0        1.20       1.333333
# 37       1.40       1.505376
# 39      94.00       1.736881
# 44      29.00       2.162565
# 43       2.50       2.380952
# 35       3.10       2.844037
# 33       1.60       2.962963
# 6       13.00       3.110048
# 36       6.10       3.210526
# 10       2.70       3.750000
# 11      37.00       4.199773
# 13    1100.00       4.246285
# 22    1700.00       5.720631
# 4       20.00       6.024096
# 42    1300.00       6.111033
# 49      16.00       6.324111
# 27       0.67       6.700000
# 32     810.00       6.877813
# 21    1500.00       9.167023
# 46    4100.00      10.910349
# 48    6000.00      12.181999
# 40      81.00      14.438503
# 15     130.00      16.250000
# 16  240000.00      19.167186
# 12     370.00      20.010817
# 18    9100.00      20.516752
# 5      440.00      21.771400
# 50    3600.00      24.760988
# 30   49000.00      26.901940
# 45       2.80      28.000000
# 19      30.00      29.411765
# 31    2400.00      32.782407
# 7     7800.00      35.049879
# 38    2600.00      42.678923
# 20     960.00      46.287367
# 41   25000.00      47.370017
# 26    1300.00      56.448111
# 25   18000.00      69.675621
# 29  160000.00      92.157936

# %% [markdown]
#  ## Conclusions
#
# The Common Wealth of Nations had a total of about 538 thousand deaths due to TB in 2013. The median shows that half of these coutries had fewer than 62 deaths. The much higher mean (over 10,000) indicates that some countries had a very high number. The least affected were Nauru and Grenada, with 1 and 2 deaths respectively, and the most affected were India and Nigeria with 160 thousand and 240 thousand deaths in a single year. However, taking the population size into account, the least affected were New Zealand and Canada with less than 1 death per 100 thousand inhabitants, and the most affected were Mozambique and Nigeria with 69 and 92 deaths per 100,000 inhabitants.
#
# One should not forget that most values are estimates, and that the chosen countries are a small sample of all the world's countries. Nevertheless, they convey the message that TB is still a major cause of fatalities, and that there is a huge disparity between countries, with several ones being highly affected.
